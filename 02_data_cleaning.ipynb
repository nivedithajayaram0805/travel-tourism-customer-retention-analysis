# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(
    r"C:\Users\Hp\Desktop\Travel-Tourism-Customer-Retention-Analysis\data\raw\data_hotel_bookings.csv"
)

df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %% [markdown]
# ## Missing Value Analysis
#
# Columns containing missing values:
# - company
# - agent
# - country
# - children

# %%
missing_percent = (df.isnull().sum()/len(df))*100

missing_percent.sort_values(ascending=False)
# Out:
# company                           94.306893
# agent                             13.686238
# country                            0.408744
# children                           0.003350
# reserved_room_type                 0.000000
# assigned_room_type                 0.000000
# booking_changes                    0.000000
# deposit_type                       0.000000
# hotel                              0.000000
# previous_cancellations             0.000000
# days_in_waiting_list               0.000000
# customer_type                      0.000000
# adr                                0.000000
# required_car_parking_spaces        0.000000
# total_of_special_requests          0.000000
# reservation_status                 0.000000
# previous_bookings_not_canceled     0.000000
# is_repeated_guest                  0.000000
# is_canceled                        0.000000
# distribution_channel               0.000000
# market_segment                     0.000000
# ...

# %%
df.drop('company', axis=1, inplace=True)

# %%
df.shape
# Out:
# (119390, 31)

# %%
df['agent'] = df['agent'].fillna(0)

# %%
df['agent'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['country'].mode()[0]
# Out:
# 'PRT'

# %%
df['country'] = df['country'].fillna(df['country'].mode()[0])

# %%
df['country'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['children'] = df['children'].fillna(df['children'].median())

# %%
df['children'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum().sort_values(ascending=False).head()
# Out:
# hotel                          0
# is_repeated_guest              0
# reservation_status             0
# total_of_special_requests      0
# required_car_parking_spaces    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(32020)

# %%
duplicates = df.duplicated().sum()

print("Duplicate Rows:", duplicates)
# Out:
# Duplicate Rows: 32020

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (87370, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87370 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87370 non-null  object
#  1   is_canceled                     87370 non-null  int64
#  2   lead_time                       87370 non-null  int64
#  3   arrival_date_year               87370 non-null  int64
#  4   arrival_date_month              87370 non-null  object
#  5   arrival_date_week_number        87370 non-null  int64
#  6   arrival_date_day_of_month       87370 non-null  int64
#  7   stays_in_weekend_nights         87370 non-null  int64
#  8   stays_in_week_nights            87370 non-null  int64
#  9   adults                          87370 non-null  int64
#  10  children                        87370 non-null  float64
#  11  babies                          87370 non-null  int64
# ...

# %%
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87370.000000  87370.000000       87370.000000
# mean       0.274969     79.911686        2016.210290
# std        0.446501     86.056471           0.686116
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87370.000000               87370.000000
# mean                  26.839533                  15.815360
# std                   13.673204                   8.834842
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %%
df.to_csv(
    r"C:\Users\Hp\Desktop\Travel-Tourism-Customer-Retention-Analysis\data\cleaned\hotel_bookings_cleaned.csv",
    index=False
)

# %%
import os

os.listdir(
    r"C:\Users\Hp\Desktop\Travel-Tourism-Customer-Retention-Analysis\data\cleaned"
)
# Out:
# ['hotel_bookings_cleaned.csv']

# %% [markdown]
# # Day 2 Conclusion
#
# Data cleaning was completed successfully.
#
# Actions performed:
# - Removed company column due to excessive missing values.
# - Filled missing values in agent, country, and children columns.
# - Removed duplicate records.
# - Verified data types and dataset structure.
# - Saved cleaned dataset for future analysis.
#
# The cleaned dataset is now ready for Exploratory Data Analysis (EDA).
